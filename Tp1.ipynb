# %% [markdown]
# <a href="https://colab.research.google.com/github/Amsatou123/VISUALISATION/blob/master/Tp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##loading packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
from pathlib import Path

# %%
# !mkdir datasets

# %%
# !ls /content/drive/MyDrive/Capacity-Building/image_datasets
# Out:
# bambey.jpg  ceraas.jpg	cows.JPG  fruits.png  landscape.JPG  save-bambey.jpeg

# %%
# !ls
# Out:
# datasets  drive  sample_data

# %%
p=Path("/content/drive/MyDrive/Capacity-Building/image_datasets")
os.chdir(p)

# %%
# !ls
# Out:
# bambey.jpg  ceraas.jpg	cows.JPG  fruits.png  landscape.JPG  save-bambey.jpeg

# %% [markdown]
# ##import data

# %%
bmb=cv2.imread('cows.JPG')
plt.imshow(bmb)
plt.show()

# %%
a,b,c=bmb.shape
print('hauteur ==',a)
print('largeur ==',b)
print('canal ==',c)
# Out:
# hauteur == 3648
# largeur == 5472
# canal == 3

# %% [markdown]
# ##visualisation

# %%
plt.imshow(img)
plt.show()

# %%
plt.imshow(img1)
plt.show()

# %%
img.shape #voir les caractéristiques du graphe
# Out:
# (3648, 5472, 3)

# %%
img1.shape
# Out:
# (2580, 4128, 3)

# %% [markdown]
# ##correction des couleurs de l'image

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.show()
